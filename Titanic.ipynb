# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split as tts, cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
f = pd.read_csv('/content/Titanic-Dataset.csv')

# %%
f.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
f.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
f.drop(columns = ['PassengerId','Name', 'Ticket', 'Cabin'], inplace = True)

# %%
f['Sex'] = f['Sex'].map({'male' : 0, 'female' : 1})
f['Age'] = f['Age'].fillna(f['Age'].median())
f['Embarked'] = f['Embarked'].fillna(f['Embarked'].mode()[0])

# %%
f.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# dtype: int64

# %%
f['Embarked'] = f['Embarked'].map({'S' : 0,'C' : 1,'Q' : 2,})

# %%
f['FamMem'] = f['Parch'] + f['SibSp']

# %%
X = f.drop(columns = ['SibSp', 'Parch','Survived'])
y = f['Survived']

# %%
X
# Out:
#      Pclass  Sex   Age     Fare  Embarked  FamMem
# 0         3    0  22.0   7.2500         0       1
# 1         1    1  38.0  71.2833         1       1
# 2         3    1  26.0   7.9250         0       0
# 3         1    1  35.0  53.1000         0       1
# 4         3    0  35.0   8.0500         0       0
# ..      ...  ...   ...      ...       ...     ...
# 886       2    0  27.0  13.0000         0       0
# 887       1    1  19.0  30.0000         0       0
# 888       3    1  28.0  23.4500         0       3
# 889       1    0  26.0  30.0000         1       0
# 890       3    0  32.0   7.7500         2       0
#
# [891 rows x 6 columns]

# %%
X_train,X_test, y_train, y_test = tts(X,y,test_size = 0.3, random_state = 2, shuffle = True)

# %%
model = LogisticRegression(max_iter= 1000)

# %%
model.fit(X_train,y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
model.coef_,model.intercept_
# Out:
# (array([[-1.15435648e+00,  2.72240120e+00, -4.53151420e-02,
#           8.71424553e-04,  1.96795867e-01, -1.93586861e-01]]),
#  array([2.38402775]))

# %%
y_pred = model.predict(X_test)

# %%
print("Accuracy:", accuracy_score(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.7910447761194029
# [[140  20]
#  [ 36  72]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.88      0.83       160
#            1       0.78      0.67      0.72       108
#
#     accuracy                           0.79       268
#    macro avg       0.79      0.77      0.78       268
# weighted avg       0.79      0.79      0.79       268

# %%
cv_scores = cross_val_score(model, X, y, cv=5, scoring='accuracy')
print("CV Accuracy:", cv_scores)
print("Mean CV Accuracy:", cv_scores.mean())
# Out:
# CV Accuracy: [0.78212291 0.79213483 0.78651685 0.78089888 0.8258427 ]
# Mean CV Accuracy: 0.7935032326909799
